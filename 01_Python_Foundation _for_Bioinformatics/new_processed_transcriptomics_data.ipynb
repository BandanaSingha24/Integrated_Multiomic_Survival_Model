# %% [markdown]
# <a href="https://colab.research.google.com/github/BandanaSingha24/Integrated_Multiomic_Survival_Model/blob/main/01_Python_Foundation%20_for_Bioinformatics/new_processed_transcriptomics_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Step 1: Load Gene Expression Data

# Load the mRNA expression data using tab separator
mrna_df = pd.read_csv('data_mrna_illumina_microarray_zscores_ref_diploid_samples.txt', sep='\t')

# Display the first 5 rows to verify the data structure
print("--- Gene Expression Data Overview ---")
display(mrna_df.head())
# Out:
# --- Gene Expression Data Overview ---
#   Hugo_Symbol  Entrez_Gene_Id  MB-0362  MB-0346  MB-0386  MB-0574  MB-0185  \
# 0        RERE             473  -0.7139   1.2266  -0.0053  -0.4399  -0.5958
# 1      RNF165          494470  -0.4606   0.3564  -0.6800  -1.0563  -0.0377
# 2        PHF7           51533  -0.3325  -1.0617   0.2587  -0.2982  -1.2422
# 3       CIDEA            1149  -0.0129  -1.0394   3.2991  -0.2632  -1.0949
# 4       TENT2          167153  -0.7853   0.0337  -0.6649   2.1640  -0.2031
#
#    MB-0503  MB-0641  MB-0201  ...  MB-6192  MB-4820  MB-5527  MB-5167  \
# 0   0.4729   0.4974  -1.1900  ...  -0.4596   1.8975   1.1120   1.1942
# 1  -0.6829  -0.2854  -0.4336  ...  -1.0927   0.9103  -0.0023  -0.2898
# 2   0.0558  -0.5011  -0.6418  ...  -0.0725   0.7219   0.1402   0.8718
# 3   1.2628   2.0796  -0.8310  ...   0.0679  -0.7126  -0.1523  -0.7593
# 4   1.0304   0.6046  -1.7557  ...   0.6400  -0.1102   1.2719   0.8178
#
# ...

# %%
#step 1:Data cleaning and Variance Filtering

# 1. Set PATIENT_ID as index so only numeric gene columns remain
if 'PATIENT_ID' in mrna_processed.columns:
    mrna_processed.set_index('PATIENT_ID', inplace=True)

# 2. Convert all remaining data to numeric just in case there are hidden strings
mrna_numeric = mrna_processed.apply(pd.to_numeric, errors='coerce')

# 3. Calculate variance safely on numeric gene columns only
variance_threshold = 0.01
low_variance_genes = mrna_numeric.columns[mrna_numeric.var() < variance_threshold].tolist()

# 4. Drop the low-variance genes
mrna_filtered = mrna_numeric.drop(columns=low_variance_genes)

# 5. Bring PATIENT_ID back as a column for Module 4 Integration
mrna_final = mrna_filtered.reset_index()

print(f"Successfully dropped {len(low_variance_genes)} low-variance genes.")
print("Final processed RNA-seq shape:", mrna_final.shape)
# Out:
# Successfully dropped 0 low-variance genes.
# Final processed RNA-seq shape: (1980, 642)

# %%
from google.colab import files

mrna_final.to_csv('md-1_processed_Transcriptomics_data.csv', index=False)

files.download('md-1_processed_Transcriptomics_data.csv')
